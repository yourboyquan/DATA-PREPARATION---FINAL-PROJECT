# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\data prep\dseb63_final_project_DP_dataset\dseb63_final_project_DP_dataset\dseb63_bureau.csv")
df
# Out:
#          SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0             5714462        Closed      currency 1         -497
# 1             5714463        Active      currency 1         -208
# 2             5714464        Active      currency 1         -203
# 3             5714465        Active      currency 1         -203
# 4             5714466        Active      currency 1         -629
# ...               ...           ...             ...          ...
# 1465320       5052629        Closed      currency 1         -532
# 1465321       5054382        Closed      currency 1         -381
# 1465322       5043236        Active      currency 1        -1441
# 1465323       5053303        Closed      currency 1         -375
# 1465324       5053356        Closed      currency 1        -2724
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                         0               -153.0             -153.0
# ...

# %%
df2 = pd.read_csv("D:\data prep\project data\dseb63_final_project_DP_dataset\dseb63_final_project_DP_dataset\dseb63_bureau_balance.csv")
df2
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0              5715448               0      C
# 1              5715448              -1      C
# 2              5715448              -2      C
# 3              5715448              -3      C
# 4              5715448              -4      C
# ...                ...             ...    ...
# 27299920       5041336             -47      X
# 27299921       5041336             -48      X
# 27299922       5041336             -49      X
# 27299923       5041336             -50      X
# 27299924       5041336             -51      X
#
# [27299925 rows x 3 columns]

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                                    column_name  percent_missing
# SK_ID_BUREAU                      SK_ID_BUREAU         0.000000
# CREDIT_ACTIVE                    CREDIT_ACTIVE         0.000000
# CREDIT_CURRENCY                CREDIT_CURRENCY         0.000000
# DAYS_CREDIT                        DAYS_CREDIT         0.000000
# CREDIT_DAY_OVERDUE          CREDIT_DAY_OVERDUE         0.000000
# DAYS_CREDIT_ENDDATE        DAYS_CREDIT_ENDDATE         6.080426
# DAYS_ENDDATE_FACT            DAYS_ENDDATE_FACT        37.170798
# AMT_CREDIT_MAX_OVERDUE  AMT_CREDIT_MAX_OVERDUE        64.732738
# CNT_CREDIT_PROLONG          CNT_CREDIT_PROLONG         0.000000
# AMT_CREDIT_SUM                  AMT_CREDIT_SUM         0.000205
# AMT_CREDIT_SUM_DEBT        AMT_CREDIT_SUM_DEBT        15.224882
# AMT_CREDIT_SUM_LIMIT      AMT_CREDIT_SUM_LIMIT        33.417160
# AMT_CREDIT_SUM_OVERDUE  AMT_CREDIT_SUM_OVERDUE         0.000000
# CREDIT_TYPE                        CREDIT_TYPE         0.000000
# ...

# %%
df.describe()
# Out:
#        SK_ID_BUREAU   DAYS_CREDIT  CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  \
# count  1.465325e+06  1.465325e+06        1.465325e+06         1.376227e+06
# mean   5.890328e+06 -1.143600e+03        8.887612e-01         4.931322e+02
# std    5.378271e+05  8.000200e+02        3.824707e+01         4.964905e+03
# min    5.000000e+06 -2.922000e+03        0.000000e+00        -4.206000e+04
# 25%    5.416944e+06 -1.671000e+03        0.000000e+00        -1.144000e+03
# 50%    5.856021e+06 -9.850000e+02        0.000000e+00        -3.340000e+02
# 75%    6.363543e+06 -4.700000e+02        0.000000e+00         4.730000e+02
# max    6.843457e+06  0.000000e+00        2.792000e+03         3.119900e+04
#
#        DAYS_ENDDATE_FACT  AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  \
# count      920652.000000            5.167800e+05        1.465325e+06
# mean        -1022.765286            3.942852e+03        7.278249e-03
# std           718.371749            2.196856e+05        1.026408e-01
# ...
