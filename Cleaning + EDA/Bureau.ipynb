# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\data prep\dseb63_final_project_DP_dataset\dseb63_final_project_DP_dataset\dseb63_bureau.csv")
df
# Out:
#          SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0             5714462        Closed      currency 1         -497
# 1             5714463        Active      currency 1         -208
# 2             5714464        Active      currency 1         -203
# 3             5714465        Active      currency 1         -203
# 4             5714466        Active      currency 1         -629
# ...               ...           ...             ...          ...
# 1465320       5052629        Closed      currency 1         -532
# 1465321       5054382        Closed      currency 1         -381
# 1465322       5043236        Active      currency 1        -1441
# 1465323       5053303        Closed      currency 1         -375
# 1465324       5053356        Closed      currency 1        -2724
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                         0               -153.0             -153.0
# 1                         0               1075.0                NaN
# 2                         0                528.0                NaN
# 3                         0                  NaN                NaN
# 4                         0               1197.0                NaN
# ...                     ...                  ...                ...
# 1465320                   0                 45.0             -227.0
# 1465321                   0               -199.0             -199.0
# 1465322                   0               2197.0                NaN
# 1465323                   0                -41.0              -19.0
# 1465324                   0              -2511.0            -2511.0
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                           NaN                   0         91323.0
# 1                           NaN                   0        225000.0
# 2                           NaN                   0        464323.5
# 3                           NaN                   0         90000.0
# 4                       77674.5                   0       2700000.0
# ...                         ...                 ...             ...
# 1465320                     NaN                   0        450000.0
# 1465321                     0.0                   0         19800.0
# 1465322                     NaN                   0       1800000.0
# 1465323                     NaN                   0        175054.5
# 1465324                     0.0                   0        101250.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                        0.0                   NaN                     0.0
# 1                   171342.0                   NaN                     0.0
# 2                        NaN                   NaN                     0.0
# 3                        NaN                   NaN                     0.0
# 4                        NaN                   NaN                     0.0
# ...                      ...                   ...                     ...
# 1465320                  0.0                   0.0                     0.0
# 1465321                  0.0                   0.0                     0.0
# 1465322            1076809.5                   0.0                     0.0
# 1465323                  NaN                   NaN                     0.0
# 1465324                  0.0                   0.0                     0.0
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY  SK_ID_CURR
# 0        Consumer credit                -131          NaN      254629
# 1            Credit card                 -20          NaN      254629
# 2        Consumer credit                 -16          NaN      254629
# 3            Credit card                 -16          NaN      254629
# 4        Consumer credit                 -21          NaN      254629
# ...                  ...                 ...          ...         ...
# 1465320  Consumer credit                 -31          NaN       66820
# 1465321  Consumer credit                -199          0.0      166221
# 1465322         Mortgage                  -2          NaN      118290
# 1465323  Consumer credit                  -4      17140.5       95296
# 1465324  Consumer credit               -2510          NaN      139955
#
# [1465325 rows x 17 columns]

# %%
number_missing = df.isnull().sum()
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'number_missing' : number_missing,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                                    column_name  number_missing  \
# SK_ID_BUREAU                      SK_ID_BUREAU               0
# CREDIT_ACTIVE                    CREDIT_ACTIVE               0
# CREDIT_CURRENCY                CREDIT_CURRENCY               0
# DAYS_CREDIT                        DAYS_CREDIT               0
# CREDIT_DAY_OVERDUE          CREDIT_DAY_OVERDUE               0
# DAYS_CREDIT_ENDDATE        DAYS_CREDIT_ENDDATE           89098
# DAYS_ENDDATE_FACT            DAYS_ENDDATE_FACT          544673
# AMT_CREDIT_MAX_OVERDUE  AMT_CREDIT_MAX_OVERDUE          948545
# CNT_CREDIT_PROLONG          CNT_CREDIT_PROLONG               0
# AMT_CREDIT_SUM                  AMT_CREDIT_SUM               3
# AMT_CREDIT_SUM_DEBT        AMT_CREDIT_SUM_DEBT          223094
# AMT_CREDIT_SUM_LIMIT      AMT_CREDIT_SUM_LIMIT          489670
# AMT_CREDIT_SUM_OVERDUE  AMT_CREDIT_SUM_OVERDUE               0
# CREDIT_TYPE                        CREDIT_TYPE               0
# DAYS_CREDIT_UPDATE          DAYS_CREDIT_UPDATE               0
# AMT_ANNUITY                        AMT_ANNUITY         1130013
# SK_ID_CURR                          SK_ID_CURR               0
#
#                         percent_missing
# SK_ID_BUREAU                   0.000000
# CREDIT_ACTIVE                  0.000000
# CREDIT_CURRENCY                0.000000
# DAYS_CREDIT                    0.000000
# CREDIT_DAY_OVERDUE             0.000000
# DAYS_CREDIT_ENDDATE            6.080426
# DAYS_ENDDATE_FACT             37.170798
# AMT_CREDIT_MAX_OVERDUE        64.732738
# CNT_CREDIT_PROLONG             0.000000
# AMT_CREDIT_SUM                 0.000205
# AMT_CREDIT_SUM_DEBT           15.224882
# AMT_CREDIT_SUM_LIMIT          33.417160
# AMT_CREDIT_SUM_OVERDUE         0.000000
# CREDIT_TYPE                    0.000000
# DAYS_CREDIT_UPDATE             0.000000
# AMT_ANNUITY                   77.116885
# SK_ID_CURR                     0.000000

# %%
sns.boxplot(df['SK_ID_BUREAU'])
# Out:
# <Axes: ylabel='SK_ID_BUREAU'>

# %%
sns.boxplot(df['CREDIT_ACTIVE'])
# Out:
# <Axes: ylabel='CREDIT_ACTIVE'>

# %%
sns.boxplot(df['CREDIT_CURRENCY'])
# Out:
# <Axes: ylabel='CREDIT_CURRENCY'>

# %%
sns.boxplot(df['DAYS_CREDIT'])
# Out:
# <Axes: ylabel='DAYS_CREDIT'>

# %%
sns.boxplot(df['CREDIT_DAY_OVERDUE'])
# Out:
# <Axes: ylabel='CREDIT_DAY_OVERDUE'>

# %%
sns.boxplot(df['DAYS_CREDIT_ENDDATE'])
# Out:
# <Axes: ylabel='DAYS_CREDIT_ENDDATE'>

# %%
sns.boxplot(df['DAYS_ENDDATE_FACT'])
# Out:
# <Axes: ylabel='DAYS_ENDDATE_FACT'>

# %%
sns.boxplot(df['AMT_CREDIT_MAX_OVERDUE'])
# Out:
# <Axes: ylabel='AMT_CREDIT_MAX_OVERDUE'>

# %%
sns.boxplot(df['CNT_CREDIT_PROLONG'])
# Out:
# <Axes: ylabel='CNT_CREDIT_PROLONG'>

# %%
sns.boxplot(df['AMT_CREDIT_SUM'])
# Out:
# <Axes: ylabel='AMT_CREDIT_SUM'>

# %%
sns.boxplot(df['AMT_CREDIT_SUM_DEBT'])
# Out:
# <Axes: ylabel='AMT_CREDIT_SUM_DEBT'>

# %%
sns.boxplot(df['AMT_CREDIT_SUM_LIMIT'])
# Out:
# <Axes: ylabel='AMT_CREDIT_SUM_LIMIT'>

# %%
sns.boxplot(df['AMT_CREDIT_SUM_OVERDUE'])
# Out:
# <Axes: ylabel='AMT_CREDIT_SUM_OVERDUE'>

# %%
sns.boxplot(df['CREDIT_TYPE'])
# Out:
# <Axes: ylabel='CREDIT_TYPE'>

# %%
sns.boxplot(df['DAYS_CREDIT_UPDATE'])
# Out:
# <Axes: ylabel='DAYS_CREDIT_UPDATE'>

# %%
sns.boxplot(df['AMT_ANNUITY'])
# Out:
# <Axes: ylabel='AMT_ANNUITY'>

# %%
numerical_data = df._get_numeric_data()

# %%
for column in numerical_data.columns:
    value_counts = numerical_data[column].apply(lambda x: '>0' if x > 0 else ('=0' if x == 0 else '<0')).value_counts()
    
    for cat in ['>0', '=0', '<0']:
        if cat not in value_counts:
            value_counts[cat] = 0
    
    nan_total = numerical_data[column].isnull().sum()
    other_value = numerical_data.shape[0] - value_counts.sum() - nan_total

    print(f'{column} has  >0: {value_counts[">0"]}, =0: {value_counts["=0"]}, <0: {value_counts["<0"]}, nan: {nan_total}, other values: {other_value}')
# Out:
# SK_ID_BUREAU has  >0: 1465325, =0: 0, <0: 0, nan: 0, other values: 0
# DAYS_CREDIT has  >0: 0, =0: 4, <0: 1465321, nan: 0, other values: 0
# CREDIT_DAY_OVERDUE has  >0: 3706, =0: 1461619, <0: 0, nan: 0, other values: 0
# DAYS_CREDIT_ENDDATE has  >0: 513371, =0: 746, <0: 951208, nan: 89098, other values: -89098
# DAYS_ENDDATE_FACT has  >0: 0, =0: 62, <0: 1465263, nan: 544673, other values: -544673
# AMT_CREDIT_MAX_OVERDUE has  >0: 107137, =0: 409643, <0: 948545, nan: 948545, other values: -948545
# CNT_CREDIT_PROLONG has  >0: 8820, =0: 1456505, <0: 0, nan: 0, other values: 0
# AMT_CREDIT_SUM has  >0: 1409394, =0: 55928, <0: 3, nan: 3, other values: -3
# AMT_CREDIT_SUM_DEBT has  >0: 369163, =0: 864650, <0: 231512, nan: 223094, other values: -223094
# AMT_CREDIT_SUM_LIMIT has  >0: 64880, =0: 910424, <0: 490021, nan: 489670, other values: -489670
# AMT_CREDIT_SUM_OVERDUE has  >0: 3644, =0: 1461681, <0: 0, nan: 0, other values: 0
# DAYS_CREDIT_UPDATE has  >0: 17, =0: 484, <0: 1464824, nan: 0, other values: 0
# AMT_ANNUITY has  >0: 168026, =0: 167286, <0: 1130013, nan: 1130013, other values: -1130013
# SK_ID_CURR has  >0: 1465324, =0: 1, <0: 0, nan: 0, other values: 0

# %%
categorical_data = df.drop(columns=numerical_data.columns)

# %%
for column in categorical_data.columns:
    unique_values = categorical_data[column].unique()
    print(f'col {column} : {list(unique_values)}\n')
# Out:
# col CREDIT_ACTIVE : ['Closed', 'Active', 'Sold', 'Bad debt']
#
# col CREDIT_CURRENCY : ['currency 1', 'currency 2', 'currency 4', 'currency 3']
#
# col CREDIT_TYPE : ['Consumer credit', 'Credit card', 'Car loan', 'Mortgage', 'Microloan', 'Loan for working capital replenishment', 'Loan for business development', 'Unknown type of loan', 'Another type of loan', 'Real estate loan', 'Loan for the purchase of equipment', 'Cash loan (non-earmarked)', 'Mobile operator loan', 'Interbank credit', 'Loan for purchase of shares (margin lending)']

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15172\868109210.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                         SK_ID_BUREAU  DAYS_CREDIT  CREDIT_DAY_OVERDUE  \
# SK_ID_BUREAU                1.000000     0.014469           -0.001878
# DAYS_CREDIT                 0.014469     1.000000           -0.028343
# CREDIT_DAY_OVERDUE         -0.001878    -0.028343            1.000000
# DAYS_CREDIT_ENDDATE         0.009412     0.231075           -0.007540
# DAYS_ENDDATE_FACT           0.017923     0.875291           -0.008780
# AMT_CREDIT_MAX_OVERDUE      0.002837    -0.014414            0.001240
# CNT_CREDIT_PROLONG          0.002658    -0.032111            0.002809
# AMT_CREDIT_SUM              0.008040     0.055663           -0.003627
# AMT_CREDIT_SUM_DEBT         0.006045     0.136678           -0.002552
# AMT_CREDIT_SUM_LIMIT       -0.003956     0.024584           -0.000310
# AMT_CREDIT_SUM_OVERDUE     -0.000491    -0.000603            0.095782
# DAYS_CREDIT_UPDATE          0.018640     0.683189           -0.018188
# AMT_ANNUITY                 0.002711     0.000144           -0.000408
# SK_ID_CURR                 -0.003786     0.001774            0.000059
#
#                         DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# SK_ID_BUREAU                       0.009412           0.017923
# DAYS_CREDIT                        0.231075           0.875291
# CREDIT_DAY_OVERDUE                -0.007540          -0.008780
# DAYS_CREDIT_ENDDATE                1.000000           0.254893
# DAYS_ENDDATE_FACT                  0.254893           1.000000
# AMT_CREDIT_MAX_OVERDUE             0.000783           0.001590
# CNT_CREDIT_PROLONG                 0.122179           0.013073
# AMT_CREDIT_SUM                     0.060284           0.069940
# AMT_CREDIT_SUM_DEBT                0.081933           0.024774
# AMT_CREDIT_SUM_LIMIT               0.088553           0.019586
# AMT_CREDIT_SUM_OVERDUE             0.001136          -0.000363
# DAYS_CREDIT_UPDATE                 0.247783           0.745192
# AMT_ANNUITY                        0.000200           0.003171
# SK_ID_CURR                         0.000344           0.002362
#
#                         AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  \
# SK_ID_BUREAU                          0.002837            0.002658
# DAYS_CREDIT                          -0.014414           -0.032111
# CREDIT_DAY_OVERDUE                    0.001240            0.002809
# DAYS_CREDIT_ENDDATE                   0.000783            0.122179
# DAYS_ENDDATE_FACT                     0.001590            0.013073
# AMT_CREDIT_MAX_OVERDUE                1.000000            0.001483
# CNT_CREDIT_PROLONG                    0.001483            1.000000
# AMT_CREDIT_SUM                        0.085068           -0.009257
# AMT_CREDIT_SUM_DEBT                   0.013129           -0.001271
# AMT_CREDIT_SUM_LIMIT                  0.000185            0.076587
# AMT_CREDIT_SUM_OVERDUE                0.015068           -0.000009
# DAYS_CREDIT_UPDATE                   -0.000620            0.018988
# AMT_ANNUITY                           0.001357           -0.000663
# SK_ID_CURR                            0.000246            0.000134
#
#                         AMT_CREDIT_SUM  AMT_CREDIT_SUM_DEBT  \
# SK_ID_BUREAU                  0.008040             0.006045
# DAYS_CREDIT                   0.055663             0.136678
# CREDIT_DAY_OVERDUE           -0.003627            -0.002552
# DAYS_CREDIT_ENDDATE           0.060284             0.081933
# DAYS_ENDDATE_FACT             0.069940             0.024774
# AMT_CREDIT_MAX_OVERDUE        0.085068             0.013129
# CNT_CREDIT_PROLONG           -0.009257            -0.001271
# AMT_CREDIT_SUM                1.000000             0.667766
# AMT_CREDIT_SUM_DEBT           0.667766             1.000000
# AMT_CREDIT_SUM_LIMIT          0.003508            -0.019174
# AMT_CREDIT_SUM_OVERDUE        0.006779             0.007909
# DAYS_CREDIT_UPDATE            0.111934             0.139080
# AMT_ANNUITY                   0.051585             0.016077
# SK_ID_CURR                   -0.001292            -0.000788
#
#                         AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# SK_ID_BUREAU                       -0.003956               -0.000491
# DAYS_CREDIT                         0.024584               -0.000603
# CREDIT_DAY_OVERDUE                 -0.000310                0.095782
# DAYS_CREDIT_ENDDATE                 0.088553                0.001136
# DAYS_ENDDATE_FACT                   0.019586               -0.000363
# AMT_CREDIT_MAX_OVERDUE              0.000185                0.015068
# CNT_CREDIT_PROLONG                  0.076587               -0.000009
# AMT_CREDIT_SUM                      0.003508                0.006779
# AMT_CREDIT_SUM_DEBT                -0.019174                0.007909
# AMT_CREDIT_SUM_LIMIT                1.000000               -0.000711
# AMT_CREDIT_SUM_OVERDUE             -0.000711                1.000000
# DAYS_CREDIT_UPDATE                  0.041893                0.003571
# AMT_ANNUITY                         0.003674                0.000420
# SK_ID_CURR                          0.000932               -0.000872
#
#                         DAYS_CREDIT_UPDATE  AMT_ANNUITY  SK_ID_CURR
# SK_ID_BUREAU                      0.018640     0.002711   -0.003786
# DAYS_CREDIT                       0.683189     0.000144    0.001774
# CREDIT_DAY_OVERDUE               -0.018188    -0.000408    0.000059
# DAYS_CREDIT_ENDDATE               0.247783     0.000200    0.000344
# DAYS_ENDDATE_FACT                 0.745192     0.003171    0.002362
# AMT_CREDIT_MAX_OVERDUE           -0.000620     0.001357    0.000246
# CNT_CREDIT_PROLONG                0.018988    -0.000663    0.000134
# AMT_CREDIT_SUM                    0.111934     0.051585   -0.001292
# AMT_CREDIT_SUM_DEBT               0.139080     0.016077   -0.000788
# AMT_CREDIT_SUM_LIMIT              0.041893     0.003674    0.000932
# AMT_CREDIT_SUM_OVERDUE            0.003571     0.000420   -0.000872
# DAYS_CREDIT_UPDATE                1.000000     0.003906   -0.000852
# AMT_ANNUITY                       0.003906     1.000000    0.004504
# SK_ID_CURR                       -0.000852     0.004504    1.000000

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
max_corr = correlation_matrix.unstack().sort_values(ascending=False).drop_duplicates()
min_corr = correlation_matrix.unstack().sort_values().drop_duplicates()
print("Các cặp features có correlation cao nhất:\n", max_corr.head())
print("\nCác cặp features có correlation thấp nhất:\n", min_corr.head())
# Out:
# Các cặp features có correlation cao nhất:
#  SK_ID_BUREAU       SK_ID_BUREAU           1.000000
# DAYS_ENDDATE_FACT  DAYS_CREDIT            0.875291
#                    DAYS_CREDIT_UPDATE     0.745192
# DAYS_CREDIT        DAYS_CREDIT_UPDATE     0.683189
# AMT_CREDIT_SUM     AMT_CREDIT_SUM_DEBT    0.667766
# dtype: float64
#
# Các cặp features có correlation thấp nhất:
#  CNT_CREDIT_PROLONG      DAYS_CREDIT            -0.032111
# CREDIT_DAY_OVERDUE      DAYS_CREDIT            -0.028343
# AMT_CREDIT_SUM_DEBT     AMT_CREDIT_SUM_LIMIT   -0.019174
# DAYS_CREDIT_UPDATE      CREDIT_DAY_OVERDUE     -0.018188
# AMT_CREDIT_MAX_OVERDUE  DAYS_CREDIT            -0.014414
# dtype: float64

# %%
df2 = pd.read_csv("D:\data prep\dseb63_final_project_DP_dataset\dseb63_final_project_DP_dataset\dseb63_application_train.csv")
df2 = df2[['SK_ID_CURR','TARGET']]

# %%
merge_table = pd.merge(df, df2, on='SK_ID_CURR', how='left')
merge_table
# Out:
#          SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0             5714462        Closed      currency 1         -497
# 1             5714463        Active      currency 1         -208
# 2             5714464        Active      currency 1         -203
# 3             5714465        Active      currency 1         -203
# 4             5714466        Active      currency 1         -629
# ...               ...           ...             ...          ...
# 1465320       5052629        Closed      currency 1         -532
# 1465321       5054382        Closed      currency 1         -381
# 1465322       5043236        Active      currency 1        -1441
# 1465323       5053303        Closed      currency 1         -375
# 1465324       5053356        Closed      currency 1        -2724
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                         0               -153.0             -153.0
# 1                         0               1075.0                NaN
# 2                         0                528.0                NaN
# 3                         0                  NaN                NaN
# 4                         0               1197.0                NaN
# ...                     ...                  ...                ...
# 1465320                   0                 45.0             -227.0
# 1465321                   0               -199.0             -199.0
# 1465322                   0               2197.0                NaN
# 1465323                   0                -41.0              -19.0
# 1465324                   0              -2511.0            -2511.0
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 0                           NaN                   0         91323.0
# 1                           NaN                   0        225000.0
# 2                           NaN                   0        464323.5
# 3                           NaN                   0         90000.0
# 4                       77674.5                   0       2700000.0
# ...                         ...                 ...             ...
# 1465320                     NaN                   0        450000.0
# 1465321                     0.0                   0         19800.0
# 1465322                     NaN                   0       1800000.0
# 1465323                     NaN                   0        175054.5
# 1465324                     0.0                   0        101250.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 0                        0.0                   NaN                     0.0
# 1                   171342.0                   NaN                     0.0
# 2                        NaN                   NaN                     0.0
# 3                        NaN                   NaN                     0.0
# 4                        NaN                   NaN                     0.0
# ...                      ...                   ...                     ...
# 1465320                  0.0                   0.0                     0.0
# 1465321                  0.0                   0.0                     0.0
# 1465322            1076809.5                   0.0                     0.0
# 1465323                  NaN                   NaN                     0.0
# 1465324                  0.0                   0.0                     0.0
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY  SK_ID_CURR  TARGET
# 0        Consumer credit                -131          NaN      254629     0.0
# 1            Credit card                 -20          NaN      254629     0.0
# 2        Consumer credit                 -16          NaN      254629     0.0
# 3            Credit card                 -16          NaN      254629     0.0
# 4        Consumer credit                 -21          NaN      254629     0.0
# ...                  ...                 ...          ...         ...     ...
# 1465320  Consumer credit                 -31          NaN       66820     NaN
# 1465321  Consumer credit                -199          0.0      166221     NaN
# 1465322         Mortgage                  -2          NaN      118290     0.0
# 1465323  Consumer credit                  -4      17140.5       95296     0.0
# 1465324  Consumer credit               -2510          NaN      139955     0.0
#
# [1465325 rows x 18 columns]
